# %% [markdown]
# ___

# %% [markdown]
# ## Indian Liver Project
#
# **Data Set Information**,
#
# - This data set contains 416 liver patient records and 167 non liver patient records.The data set was collected from test samples in North East of Andhra Pradesh, India.
#     - 'is_patient' is a class label used to divide into groups(liver patient or not).
#     - This data set contains 441 male patient records and 142 female patient records.
#     - Any patient whose age exceeded 89 is listed as being of age "90".
#
# **Attribute Information**:
#
# - **age**: Age of the patient
# - **gender**: Gender of the patient
# - **tot_bilirubin**: Total Bilirubin
# - **direct_bilirubin**: Direct Bilirubin
# - **alkphos Alkaline**: Phosphotase
# - **sgpt**: Alamine Aminotransferase
# - **sgot**: Aspartate Aminotransferase
# - **tot_proteins**: Total Protiens
# - **albumin**: Albumin
# - **ag_ratio**: Albumin and Globulin Ratio
# - **is_patient**: Selector field used to split the data into two sets (labeled by the experts)
#
# **[data source](https://www.kaggle.com/jeevannagaraj/indian-liver-patient-dataset)**

# %%
## =======================================================
#.     Importing Necessary Tools For the project
## =======================================================

import pandas as pd; import numpy as np
from sklearn.metrics import accuracy_score,  roc_auc_score
from sklearn.model_selection import train_test_split

# Import models that make the ensemble 
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.ensemble import RandomForestClassifier

# Import Preprocessing tools
from sklearn.preprocessing import StandardScaler

# Import VotingClassifier
from sklearn.ensemble import VotingClassifier

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
## ================================================
#    Read and explore the data
# =================================================
liver = pd.read_csv('liver.csv')
liver.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 583 entries, 0 to 582
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   age               583 non-null    int64
#  1   gender            583 non-null    object
#  2   tot_bilirubin     583 non-null    float64
#  3   direct_bilirubin  583 non-null    float64
#  4   tot_proteins      583 non-null    int64
#  5   albumin           583 non-null    int64
#  6   ag_ratio          583 non-null    int64
#  7   sgpt              583 non-null    float64
#  8   sgot              583 non-null    float64
#  9   alkphos           579 non-null    float64
#  10  is_patient        583 non-null    int64
# dtypes: float64(5), int64(5), object(1)
# memory usage: 50.2+ KB

# %%
liver.head()
# Out:
#    age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 0   65  Female            0.7               0.1           187       16
# 1   62    Male           10.9               5.5           699       64
# 2   62    Male            7.3               4.1           490       60
# 3   58    Male            1.0               0.4           182       14
# 4   72    Male            3.9               2.0           195       27
#
#    ag_ratio  sgpt  sgot  alkphos  is_patient
# 0        18   6.8   3.3     0.90           1
# 1       100   7.5   3.2     0.74           1
# 2        68   7.0   3.3     0.89           1
# 3        20   6.8   3.4     1.00           1
# 4        59   7.3   2.4     0.40           1

# %%
# Checking for missing data
# ------------------------
liver.isnull().sum()
# Out:
# age                 0
# gender              0
# tot_bilirubin       0
# direct_bilirubin    0
# tot_proteins        0
# albumin             0
# ag_ratio            0
# sgpt                0
# sgot                0
# alkphos             4
# is_patient          0
# dtype: int64

# %%
liver[liver['alkphos'].isnull()]
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 209   45  Female            0.9               0.3           189       23
# 241   51    Male            0.8               0.2           230       24
# 253   35  Female            0.6               0.2           180       12
# 312   27    Male            1.3               0.6           106       25
#
#      ag_ratio  sgpt  sgot  alkphos  is_patient
# 209        33   6.6   3.9      NaN           1
# 241        46   6.5   3.1      NaN           1
# 253        15   5.2   2.7      NaN           2
# 312        54   8.5   4.8      NaN           2

# %% [markdown]
# ### Missing data Imputation
#
# The missing data points are coded correctly as `NaN`. There are only four data points, we can drop them. But, We are going to use a simple imputation method **mean imputation**.
#
# In order to perform **mean imputation** we can either use pandas `fillna()` method, which we have seen before, or `SimpleImputer` from `sklearn.impute`. Which is the one we are going to use here.
#
# **Here are the steps for doing simple imputation**,
#  - Import `SimpleImputer` from `sklearn.impute`
#  - Instantiate the **Imputer**.
#  - Set the stratey of imputing such as **strategy = 'mean')
#  - Fit and transform the data using `fit_transform()` the imputer method.

# %%
## ======================================
#     Missing Data Imputation
## ======================================

from sklearn.impute import SimpleImputer
imp = SimpleImputer(missing_values=np.nan, strategy='mean')

#Imputing values
#================
liver['alkphos']=imp.fit_transform(liver[['alkphos']])

# Check the missing data again
#===========================
liver['alkphos'].isnull().sum()
# Out:
# 0

# %%
## ============================================
#         Encoding the gender example
##==============================================
liver['gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
# """
# Here I am going to use the apply method to code the gender variable 
# Female = 0 and Male = 1
# """

liver['gender'] = liver['gender'].apply(lambda x:1 if x == 'Male' else 0)
liver['gender'].unique()
# Out:
# array([0, 1])

# %% [markdown]
#  In this tutorial, we will skip Data Exploration and focus on how the ensemble algorithm woks

# %%
#Now it's time to see the correlation
# ====================================
liver.corr().style.background_gradient(cmap='PuBu')
# Out:
# <style type="text/css">
# #T_a3b14_row0_col0, #T_a3b14_row1_col1, #T_a3b14_row2_col2, #T_a3b14_row3_col3, #T_a3b14_row4_col4, #T_a3b14_row5_col5, #T_a3b14_row6_col6, #T_a3b14_row7_col7, #T_a3b14_row8_col8, #T_a3b14_row9_col9, #T_a3b14_row10_col10 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a3b14_row0_col1, #T_a3b14_row9_col5 {
#   background-color: #e9e5f1;
#   color: #000000;
# }
# #T_a3b14_row0_col2, #T_a3b14_row6_col0 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_a3b14_row0_col3 {
#   background-color: #dad9ea;
#   color: #000000;
# }
# #T_a3b14_row0_col4, #T_a3b14_row1_col0, #T_a3b14_row1_col2 {
#   background-color: #ced0e6;
#   color: #000000;
# }
# #T_a3b14_row0_col5, #T_a3b14_row5_col10 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_a3b14_row0_col6, #T_a3b14_row8_col5 {
#   background-color: #eee8f3;
#   color: #000000;
# }
# #T_a3b14_row0_col7, #T_a3b14_row0_col8, #T_a3b14_row3_col10, #T_a3b14_row4_col9, #T_a3b14_row8_col0, #T_a3b14_row8_col1, #T_a3b14_row8_col2, #T_a3b14_row9_col4, #T_a3b14_row10_col2, #T_a3b14_row10_col3, #T_a3b14_row10_col5, #T_a3b14_row10_col6 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a3b14_row0_col9, #T_a3b14_row8_col3, #T_a3b14_row9_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_a3b14_row0_col10, #T_a3b14_row1_col7, #T_a3b14_row9_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_a3b14_row1_col3 {
#   background-color: #c6cce3;
#   color: #000000;
# }
# #T_a3b14_row1_col4, #T_a3b14_row2_col1, #T_a3b14_row7_col4 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_a3b14_row1_col5 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_a3b14_row1_col6 {
#   background-color: #dbdaeb;
#   color: #000000;
# }
# #T_a3b14_row1_col8, #T_a3b14_row4_col7, #T_a3b14_row6_col7, #T_a3b14_row6_col9 {
#   background-color: #eae6f1;
#   color: #000000;
# }
# #T_a3b14_row1_col9, #T_a3b14_row5_col8, #T_a3b14_row10_col7 {
#   background-color: #dfddec;
#   color: #000000;
# }
# #T_a3b14_row1_col10 {
#   background-color: #ebe6f2;
#   color: #000000;
# }
# #T_a3b14_row2_col0 {
#   background-color: #d7d6e9;
#   color: #000000;
# }
# #T_a3b14_row2_col3 {
#   background-color: #045382;
#   color: #f1f1f1;
# }
# #T_a3b14_row2_col4, #T_a3b14_row3_col6, #T_a3b14_row5_col2 {
#   background-color: #acc0dd;
#   color: #000000;
# }
# #T_a3b14_row2_col5, #T_a3b14_row6_col4, #T_a3b14_row8_col10, #T_a3b14_row9_col10 {
#   background-color: #b7c5df;
#   color: #000000;
# }
# #T_a3b14_row2_col6, #T_a3b14_row10_col8 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_a3b14_row2_col7 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_a3b14_row2_col8 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_a3b14_row2_col9, #T_a3b14_row2_col10 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_a3b14_row3_col0 {
#   background-color: #d8d7e9;
#   color: #000000;
# }
# #T_a3b14_row3_col1 {
#   background-color: #e0deed;
#   color: #000000;
# }
# #T_a3b14_row3_col2 {
#   background-color: #045483;
#   color: #f1f1f1;
# }
# #T_a3b14_row3_col4, #T_a3b14_row7_col9 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_a3b14_row3_col5 {
#   background-color: #b1c2de;
#   color: #000000;
# }
# #T_a3b14_row3_col7, #T_a3b14_row6_col1 {
#   background-color: #e5e1ef;
#   color: #000000;
# }
# #T_a3b14_row3_col8, #T_a3b14_row3_col9 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_a3b14_row4_col0, #T_a3b14_row4_col6 {
#   background-color: #c8cde4;
#   color: #000000;
# }
# #T_a3b14_row4_col1, #T_a3b14_row7_col0 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# #T_a3b14_row4_col2 {
#   background-color: #afc1dd;
#   color: #000000;
# }
# #T_a3b14_row4_col3, #T_a3b14_row5_col3 {
#   background-color: #a2bcda;
#   color: #000000;
# }
# #T_a3b14_row4_col5 {
#   background-color: #d1d2e6;
#   color: #000000;
# }
# #T_a3b14_row4_col8 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_a3b14_row4_col10 {
#   background-color: #f8f1f8;
#   color: #000000;
# }
# #T_a3b14_row5_col0, #T_a3b14_row6_col8 {
#   background-color: #e8e4f0;
#   color: #000000;
# }
# #T_a3b14_row5_col1 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_a3b14_row5_col4 {
#   background-color: #c2cbe2;
#   color: #000000;
# }
# #T_a3b14_row5_col6, #T_a3b14_row8_col7 {
#   background-color: #04649d;
#   color: #f1f1f1;
# }
# #T_a3b14_row5_col7 {
#   background-color: #ede7f2;
#   color: #000000;
# }
# #T_a3b14_row5_col9 {
#   background-color: #dedcec;
#   color: #000000;
# }
# #T_a3b14_row6_col2 {
#   background-color: #a5bddb;
#   color: #000000;
# }
# #T_a3b14_row6_col3 {
#   background-color: #9ab8d8;
#   color: #000000;
# }
# #T_a3b14_row6_col5 {
#   background-color: #04639b;
#   color: #f1f1f1;
# }
# #T_a3b14_row6_col10 {
#   background-color: #f4edf6;
#   color: #000000;
# }
# #T_a3b14_row7_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# #T_a3b14_row7_col2 {
#   background-color: #e1dfed;
#   color: #000000;
# }
# #T_a3b14_row7_col3 {
#   background-color: #dcdaeb;
#   color: #000000;
# }
# #T_a3b14_row7_col5, #T_a3b14_row10_col0 {
#   background-color: #f0eaf4;
#   color: #000000;
# }
# #T_a3b14_row7_col6 {
#   background-color: #eee9f3;
#   color: #000000;
# }
# #T_a3b14_row7_col8 {
#   background-color: #046299;
#   color: #f1f1f1;
# }
# #T_a3b14_row7_col10 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_a3b14_row8_col4, #T_a3b14_row8_col6 {
#   background-color: #f7f0f7;
#   color: #000000;
# }
# #T_a3b14_row8_col9 {
#   background-color: #0771b1;
#   color: #f1f1f1;
# }
# #T_a3b14_row9_col0, #T_a3b14_row10_col4 {
#   background-color: #f9f2f8;
#   color: #000000;
# }
# #T_a3b14_row9_col3 {
#   background-color: #faf2f8;
#   color: #000000;
# }
# #T_a3b14_row9_col6 {
#   background-color: #f4eef6;
#   color: #000000;
# }
# #T_a3b14_row9_col7 {
#   background-color: #adc1dd;
#   color: #000000;
# }
# #T_a3b14_row9_col8 {
#   background-color: #056faf;
#   color: #f1f1f1;
# }
# #T_a3b14_row10_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_a3b14_row10_col9 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# </style>
# <table id="T_a3b14">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a3b14_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_a3b14_level0_col1" class="col_heading level0 col1" >gender</th>
#       <th id="T_a3b14_level0_col2" class="col_heading level0 col2" >tot_bilirubin</th>
#       <th id="T_a3b14_level0_col3" class="col_heading level0 col3" >direct_bilirubin</th>
#       <th id="T_a3b14_level0_col4" class="col_heading level0 col4" >tot_proteins</th>
#       <th id="T_a3b14_level0_col5" class="col_heading level0 col5" >albumin</th>
#       <th id="T_a3b14_level0_col6" class="col_heading level0 col6" >ag_ratio</th>
#       <th id="T_a3b14_level0_col7" class="col_heading level0 col7" >sgpt</th>
#       <th id="T_a3b14_level0_col8" class="col_heading level0 col8" >sgot</th>
#       <th id="T_a3b14_level0_col9" class="col_heading level0 col9" >alkphos</th>
#       <th id="T_a3b14_level0_col10" class="col_heading level0 col10" >is_patient</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a3b14_level0_row0" class="row_heading level0 row0" >age</th>
#       <td id="T_a3b14_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_a3b14_row0_col1" class="data row0 col1" >0.056560</td>
#       <td id="T_a3b14_row0_col2" class="data row0 col2" >0.011763</td>
#       <td id="T_a3b14_row0_col3" class="data row0 col3" >0.007529</td>
#       <td id="T_a3b14_row0_col4" class="data row0 col4" >0.080425</td>
#       <td id="T_a3b14_row0_col5" class="data row0 col5" >-0.086883</td>
#       <td id="T_a3b14_row0_col6" class="data row0 col6" >-0.019910</td>
#       <td id="T_a3b14_row0_col7" class="data row0 col7" >-0.187461</td>
#       <td id="T_a3b14_row0_col8" class="data row0 col8" >-0.265924</td>
#       <td id="T_a3b14_row0_col9" class="data row0 col9" >-0.216089</td>
#       <td id="T_a3b14_row0_col10" class="data row0 col10" >-0.137351</td>
#     </tr>
#     <tr>
#       <th id="T_a3b14_level0_row1" class="row_heading level0 row1" >gender</th>
#       <td id="T_a3b14_row1_col0" class="data row1 col0" >0.056560</td>
#       <td id="T_a3b14_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_a3b14_row1_col2" class="data row1 col2" >0.089291</td>
#       <td id="T_a3b14_row1_col3" class="data row1 col3" >0.100436</

# %%
X = liver.drop('is_patient', axis=1)
y = liver['is_patient'].values

X_train, X_test, y_train, y_test = train_test_split(
                                    X, y,
                                    test_size= 0.3,
                                    random_state= 1)

# %%
X_train.head()
# Out:
#      age  gender  tot_bilirubin  direct_bilirubin  tot_proteins  albumin  \
# 440   49       0            0.8               0.2           198       23
# 110   24       0            0.7               0.2           188       11
# 396   74       1            1.0               0.3           175       30
# 311   54       0           23.2              12.6           574       43
# 395   45       1            0.8               0.2           140       24
#
#      ag_ratio  sgpt  sgot  alkphos
# 440        20   7.0   4.3     1.50
# 110        10   5.5   2.3     0.71
# 396        32   6.4   3.4     1.10
# 311        47   7.2   3.5     0.90
# 395        20   6.3   3.2     1.00

# %%
# Scaling the data
# ---------------

scaler=StandardScaler()

X_train = scaler.fit_transform(X_train)

X_test = scaler.transform(X_test)

# %%
# Instantiate logreg
logreg = LogisticRegression(random_state=1)

# Instantiate knn
knn = KNN(n_neighbors=27)

# Instantiate dt
dt = DecisionTreeClassifier(min_samples_leaf= 0.13, 
                            random_state=1)

# Define the list classifiers
classifiers = [('Logistic Regression', logreg), 
               ('K Nearest Neighbours', knn), 
               ('Classification Tree', dt)]

# Iterate over the pre-defined list of classifiers
for clf_name, clf in classifiers:    
 
    # Fit clf to the training set
    clf.fit(X_train, y_train)    
   
    # Predict y_pred
    y_pred = clf.predict(X_test)
    
    # Calculate accuracy
    accuracy = accuracy_score(y_pred, y_test) 
   
    # Evaluate clf's accuracy on the test set
    print('{:20}: {:.3f}'.format(clf_name,  accuracy))
# Out:
# Logistic Regression : 0.726
# K Nearest Neighbours: 0.720
# Classification Tree : 0.726

# %%
# Import VotingClassifier from sklearn.ensemble
from sklearn.ensemble import VotingClassifier

# Instantiate a VotingClassifier vc
vc = VotingClassifier(estimators=classifiers)     

# Fit vc to the training set
vc.fit(X_train, y_train)   

# Evaluate the test set predictions
y_pred = vc.predict(X_test)

# Calculate accuracy score
accuracy = accuracy_score(y_pred, y_test)
print('Voting Classifier: {:.3f}'.format(accuracy))
# Out:
# Voting Classifier: 0.737
